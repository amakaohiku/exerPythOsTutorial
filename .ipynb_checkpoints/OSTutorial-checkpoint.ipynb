# %%
import os

# %%
print(dir(os))
# Out:
# ['CLD_CONTINUED', 'CLD_DUMPED', 'CLD_EXITED', 'CLD_TRAPPED', 'DirEntry', 'EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_LOCK', 'F_OK', 'F_TEST', 'F_TLOCK', 'F_ULOCK', 'MutableMapping', 'NGROUPS_MAX', 'O_ACCMODE', 'O_APPEND', 'O_ASYNC', 'O_CLOEXEC', 'O_CREAT', 'O_DIRECTORY', 'O_DSYNC', 'O_EXCL', 'O_EXLOCK', 'O_NDELAY', 'O_NOCTTY', 'O_NOFOLLOW', 'O_NONBLOCK', 'O_RDONLY', 'O_RDWR', 'O_SHLOCK', 'O_SYNC', 'O_TRUNC', 'O_WRONLY', 'POSIX_SPAWN_CLOSE', 'POSIX_SPAWN_DUP2', 'POSIX_SPAWN_OPEN', 'PRIO_PGRP', 'PRIO_PROCESS', 'PRIO_USER', 'P_ALL', 'P_NOWAIT', 'P_NOWAITO', 'P_PGID', 'P_PID', 'P_WAIT', 'PathLike', 'RTLD_GLOBAL', 'RTLD_LAZY', 'RTLD_LOCAL', 'RTLD_NODELETE', 'RTLD_NOLOAD', 'RTLD_NOW', 'R_OK', 'SCHED_FIFO', 'SCHED_OTHER', 'SCHED_RR', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'ST_NOSUID', 'ST_RDONLY', 'TMP_MAX', 'WCONTINUED'
# ...

# %%
print(os.getcwd())
# Out:
# /Users/nwamakaohiku/Desktop/6806/exerPythOsTutorial

# %%
os.chdir('/Users/nwamakaohiku/Desktop/')

# %%
print(os.getcwd())
# Out:
# /Users/nwamakaohiku/Desktop

# %%
 os.listdir()
# Out:
# ['7 Best Images of Preschool Writing Worksheets Free Printable Letters - Free Printable Alphabet Lette.pdf',
#  'School Work',
#  'Scan 3.jpeg',
#  '.pythonlearn.pdf.icloud',
#  'Settings_files',
#  'NN CV.docx',
#  'P&C',
#  'Course Modules_ Grade 1 - Homeroom O.htm',
#  'Purchases',
#  'Screen Shot 2020-08-30 at 11.28.31 PM.png',
#  '.DS_Store',
#  'SSI Reentry number.webarchive',
#  'HDD.docx',
#  'Python',
#  '.localized',
#  '.ebook-5.pdf.icloud',
#  'StataIC',
#  '~$udy design 2.0.docx',
#  'myProject',
#  'Screen Shot 2020-09-05 at 1.19.40 AM.png',
#  '~$w does the United States.docx',
#  'ebook-2.pdf',
#  '~$ite a letter to the schools introducing ourselves and outlining how we can help.docx',
#  'Listen to us.docx',
#  'Church',
#  'ebook-3.pdf',
#  'Scan 1 copy.jpeg',
#  'Business',
#  'Family',
#  '~$aluation.docx',
#  'ecgen-radiology',
#  'exerPythCheckInstal',
#  'Academic Records.pdf',
#  'Course Modules_ Grade 1 - Homeroom O_files',
#  'Pics',
#  'ebook-4.pdf',
# ...

# %%
os.mkdir('NURS6806-2')

# %%
 os.listdir()
# Out:
# ['7 Best Images of Preschool Writing Worksheets Free Printable Letters - Free Printable Alphabet Lette.pdf',
#  'School Work',
#  'Scan 3.jpeg',
#  '.pythonlearn.pdf.icloud',
#  'Settings_files',
#  'NN CV.docx',
#  'P&C',
#  'Course Modules_ Grade 1 - Homeroom O.htm',
#  'Purchases',
#  'Screen Shot 2020-08-30 at 11.28.31 PM.png',
#  '.DS_Store',
#  'NURS6806-2',
#  'SSI Reentry number.webarchive',
#  'HDD.docx',
#  'Python',
#  '.localized',
#  '.ebook-5.pdf.icloud',
#  'StataIC',
#  '~$udy design 2.0.docx',
#  'myProject',
#  'Screen Shot 2020-09-05 at 1.19.40 AM.png',
#  '~$w does the United States.docx',
#  'ebook-2.pdf',
#  '~$ite a letter to the schools introducing ourselves and outlining how we can help.docx',
#  'Listen to us.docx',
#  'Church',
#  'ebook-3.pdf',
#  'Scan 1 copy.jpeg',
#  'Business',
#  'Family',
#  '~$aluation.docx',
#  'ecgen-radiology',
#  'exerPythCheckInstal',
#  'Academic Records.pdf',
#  'Course Modules_ Grade 1 - Homeroom O_files',
#  'Pics',
# ...

# %%
os.rmdir('NURS6806-2')

# %%
 os.listdir()
# Out:
# ['7 Best Images of Preschool Writing Worksheets Free Printable Letters - Free Printable Alphabet Lette.pdf',
#  'School Work',
#  'Scan 3.jpeg',
#  '.pythonlearn.pdf.icloud',
#  'Settings_files',
#  'NN CV.docx',
#  'P&C',
#  'Course Modules_ Grade 1 - Homeroom O.htm',
#  'Purchases',
#  'Screen Shot 2020-08-30 at 11.28.31 PM.png',
#  '.DS_Store',
#  'SSI Reentry number.webarchive',
#  'HDD.docx',
#  'Python',
#  '.localized',
#  '.ebook-5.pdf.icloud',
#  'StataIC',
#  '~$udy design 2.0.docx',
#  'myProject',
#  'Screen Shot 2020-09-05 at 1.19.40 AM.png',
#  '~$w does the United States.docx',
#  'ebook-2.pdf',
#  '~$ite a letter to the schools introducing ourselves and outlining how we can help.docx',
#  'Listen to us.docx',
#  'Church',
#  'ebook-3.pdf',
#  'Scan 1 copy.jpeg',
#  'Business',
#  'Family',
#  '~$aluation.docx',
#  'ecgen-radiology',
#  'exerPythCheckInstal',
#  'Academic Records.pdf',
#  'Course Modules_ Grade 1 - Homeroom O_files',
#  'Pics',
#  'ebook-4.pdf',
# ...

# %%
os.makedirs('NURS6806-2/DEMO')

# %%
os.listdir()
# Out:
# ['7 Best Images of Preschool Writing Worksheets Free Printable Letters - Free Printable Alphabet Lette.pdf',
#  'School Work',
#  'Scan 3.jpeg',
#  '.pythonlearn.pdf.icloud',
#  'Settings_files',
#  'NN CV.docx',
#  'P&C',
#  'Course Modules_ Grade 1 - Homeroom O.htm',
#  'Purchases',
#  'Screen Shot 2020-08-30 at 11.28.31 PM.png',
#  '.DS_Store',
#  'NURS6806-2',
#  'SSI Reentry number.webarchive',
#  'HDD.docx',
#  'Python',
#  '.localized',
#  '.ebook-5.pdf.icloud',
#  'StataIC',
#  '~$udy design 2.0.docx',
#  'myProject',
#  'Screen Shot 2020-09-05 at 1.19.40 AM.png',
#  '~$w does the United States.docx',
#  'ebook-2.pdf',
#  '~$ite a letter to the schools introducing ourselves and outlining how we can help.docx',
#  'Listen to us.docx',
#  'Church',
#  'ebook-3.pdf',
#  'Scan 1 copy.jpeg',
#  'Business',
#  'Family',
#  '~$aluation.docx',
#  'ecgen-radiology',
#  'exerPythCheckInstal',
#  'Academic Records.pdf',
#  'Course Modules_ Grade 1 - Homeroom O_files',
#  'Pics',
# ...

# %%
os.removedirs('NURS6806-2/DEMO')

# %%
os.rename('NURS6806','NURS6806-1')

# %%
print(os.stat('NURS6806-1'))
# Out:
# os.stat_result(st_mode=16877, st_ino=16092113, st_dev=16777220, st_nlink=4, st_uid=501, st_gid=20, st_size=128, st_atime=1599023150, st_mtime=1599023149, st_ctime=1599621864)

# %%
 from datetime import datetime

# %%
mod_time = os.stat('NURS6806-1').st_mtime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# 2020-09-01 23:05:49

# %%
for dirpath, dirnames, filenames in os.walk('/Users/nwamakaohiku/Desktop/'):
    print('current path:', dirpath)
    print('directories:', dirnames)
    print('files:', filenames)
    print()
# Out:
# current path: /Users/nwamakaohiku/Desktop/
# directories: ['School Work', 'Settings_files', 'P&C', 'Purchases', 'Python', 'myProject', 'Church', 'Business', 'Family', 'ecgen-radiology', 'exerPythCheckInstal', 'Course Modules_ Grade 1 - Homeroom O_files', 'Pics', 'BIOSTAT', 'My Children', 'NURS6806-1', 'Work', "Ejiemen's Howework", '.ipynb_checkpoints', 'NGO', '.git', 'mod.py', '6806']
# ...

# %%
print(os.environ.get('HOME')
# Out:
# /Users/nwamakaohiku

# %%
file_path = os.path.join(os.environ.get('HOME'), 'test.txt')

# %%
print(file_path)
# Out:
# /Users/nwamakaohiku/test.txt

# %%
print(os.path.basename('/tmp/test.txt'))
# Out:
# test.txt

# %%
print(os.path.dirname('/tmp/test.txt'))
# Out:
# /tmp

# %%
print(os.path.split('/tmp/test.txt'))
# Out:
# ('/tmp', 'test.txt')

# %%
print(os.path.exists('/tmp/test.txt'))
# Out:
# False

# %%
print(os.path.isdir('/tmp/fghfghg'))
# Out:
# False

# %%
print(os.path.isfile('/tmp/fghfghg'))
# Out:
# False

# %%
print(os.path.splitext('/tmp/test.txt'))
# Out:
# ('/tmp/test', '.txt')

# %%
#https://docs.python.org/3/contents.html

# %%
#https://www.youtube.com/watch?v=tJxcKyFMTGo
